# %%
import sys
sys.path.append('D:/Python/Projecten/pypv/lib')  # add my own lib folder to Python's search path
sys.path.append('D:/Python/Projecten/pypv/datafiles')  # add the folder with the py-script for the horizon profiles

# %%
from IPython.display import HTML
import sun
import photovoltaic as pv
from quantities.date_time import Date, ANY_YEAR

# %% [markdown]
# # 1. PV SYSTEM DESIGN

# %% [markdown]
# ## 1.1 Set Up Geographic Location and Horizon Profiles

# %%
loc = sun.Location(
    name='Ghent',
    region='Belgium',
    latitude=51.07,
    longitude=3.69,
    altitude=9.0
)

# %% [markdown]
# **Import horizon profiles from Python script 'horizon_profiles.py'**

# %%
from horizon_profiles import hp_01, hp_02

# %% [markdown]
# **Plot sun path diagrams with horizon profile 'hp_01' (front of flat roof)**

# %%
spl = [sun.SunPath(loc, Date(ANY_YEAR, m, 21)) for m in range(1, 13)]
p = sun.plot_sun_path_diagram(spl, hp_01, size=(14, 8), dpi=96)
p.show_graph()

# %% [markdown]
# **Plot sun path diagram with horizon profile 'hp_02' (at the end of the flat roof)**

# %%
p = sun.plot_sun_path_diagram(spl, hp_02, size=(14, 8), dpi=96)
p.show_graph()

# %% [markdown]
# ## 1.2 Set Up PV Matrix

# %% [markdown]
# ### Solar Panels

# %% [markdown]
# **Photovoltaic specifications of solar panels**

# %%
pv_char = pv.PhotoVoltaicCharacteristics(
    pv.STC(Isc=9.97, Voc=39.4, Impp=9.63, Vmpp=31.2),
    pv.TemperatureCoefficients(cIsc=0.05, cVoc=-0.29, cPmpp=-0.4),
    noct=48.0
)

# %% [markdown]
# **Solar panels with eastern orientation**

# %%
solar_panel_east_hp01 = pv.SolarPanel(
    loc=loc,
    orient=pv.Orientation(azimuth=78.0, tilt=20.0),
    dim=pv.Dimensions(width=0.99, height=1.66),
    pv_char=pv_char,
    hz_profile=hp_01
)

# %%
solar_panel_east_hp02 = pv.SolarPanel(
    loc=loc,
    orient=pv.Orientation(azimuth=78.0, tilt=20.0),
    dim=pv.Dimensions(width=0.99, height=1.66),
    pv_char=pv_char,
    hz_profile=hp_02
)

# %% [markdown]
# **Solar panel with western orientation**

# %%
solar_panel_west_hp01 = pv.SolarPanel(
    loc=loc,
    orient=pv.Orientation(azimuth=258.0, tilt=20.0),
    dim=pv.Dimensions(width=0.99, height=1.66),
    pv_char=pv_char,
    hz_profile=hp_01
)

# %%
solar_panel_west_hp02 = pv.SolarPanel(
    loc=loc,
    orient=pv.Orientation(azimuth=258.0, tilt=20.0),
    dim=pv.Dimensions(width=0.99, height=1.66),
    pv_char=pv_char,
    hz_profile=hp_02
)

# %% [markdown]
# ### Solar Panel Matrix

# %% [markdown]
# 2 parallel strings with 9 solar panels

# %%
row_num = 9  # number of solar panels in one string
col_num = 2  # number of parallel strings

pv_matrix = pv.SolarPanelMatrix('PVM', row_num=row_num, col_num=col_num)
for r in range(row_num):
    for c in range(col_num):
        if c == 0:  # west
            if 0 <= r < 5:
                pv_matrix.add_solar_panel(solar_panel_west_hp01, r, c)
            if 5 <= r < 9:
                pv_matrix.add_solar_panel(solar_panel_west_hp02, r, c)
        if c == 1:  # east
            if 0 <= r < 5:
                pv_matrix.add_solar_panel(solar_panel_east_hp01, r, c)
            if 5 <= r < 9:
                pv_matrix.add_solar_panel(solar_panel_east_hp02, r, c)

# %% [markdown]
# **PV matrix performance at STC**

# %%
pv_matrix.set_operating_conditions(Gsurf=1000.0, Tcell=25.0)  # STC conditions
display(HTML(f'- peak power = <b>{pv_matrix.get_mpp_power() / 1000.0:.1f}</b> kWp'))
display(HTML(f'- MPP current = <b>{pv_matrix.get_mpp_current():.1f}</b> A'))
display(HTML(f'- MPP voltage = <b>{pv_matrix.get_mpp_voltage():.1f}</b> V'))
display(HTML(f'- short circuit current = <b>{pv_matrix.get_sc_current():.1f}</b> A'))
display(HTML(f'- open circuit voltage = <b>{pv_matrix.get_oc_voltage():.1f}</b> V'))
# Out:
# - peak power = <b>5.4</b> kWp
# - MPP current = <b>19.3</b> A
# - MPP voltage = <b>280.8</b> V
# - short circuit current = <b>19.9</b> A
# - open circuit voltage = <b>354.6</b> V

# %% [markdown]
# **Required cross section of string cables**

# %%
pv_matrix.string_cables.set_cable_lengths(25, 25)
cs_min = pv_matrix.string_cables.calc_min_cross_sections()
display(HTML(f'minimum required string cable cross section {pv_matrix.id} = <b>{min(cs_min):.1f}</b> mm²'))
# Out:
# minimum required string cable cross section PVM = <b>3.2</b> mm²

# %% [markdown]
# ## 1.3 Set Up PV Inverters

# %% [markdown]
# **Add PV matrix to inverter**

# %%
pv_inverter = pv.Inverter('INVERTER')
pv_inverter.add_pv_matrix(pv_matrix)

# %% [markdown]
# **Inverter working range requirements**

# %%
inv_req = pv_inverter.get_requirements()
display(HTML(
    f"- minimum allowable value of nominal AC power: <b>{inv_req['Pac_min'][0] / 1000.0:.3f}</b> kW<br>"
    f"- maximum allowable value of nominal AC power: <b>{inv_req['Pac_max'][0] / 1000.0:.3f}</b> kW<br>"
    f"- minimum allowable value of maximum DC voltage: <b>{inv_req['Vdc_max'][0]:.3f}</b> V<br>"
    f"- maximum allowable value of minimum MPP voltage: <b>{inv_req['Vmpp_min'][0]:.3f}</b> V<br>"
    f"- minimum allowable value of maximum DC current: <b>{inv_req['Idc_max'][0]:.3f}</b> A<br>"
    f"- minimum allowable value of maximum DC power: <b>{inv_req['Pdc_max'][0] / 1000.0:.3f}</b> kW."
))
# Out:
# - minimum allowable value of nominal AC power: <b>4.327</b> kW<br>- maximum allowable value of nominal AC power: <b>6.490</b> kW<br>- minimum allowable value of maximum DC voltage: <b>390.592</b> V<br>- maximum allowable value of minimum MPP voltage: <b>244.156</b> V<br>- minimum allowable value of maximum DC current: <b>24.075</b> A<br>- minimum allowable value of maximum DC power: <b>5.601</b> kW.

# %%
graph = pv_inverter.plot_working_range(required_range=True, fig_size=(14, 8), dpi=96)
graph.show_graph()

# %% [markdown]
# # 2. SIZING PV SYSTEM

# %% [markdown]
# ## 2.1 Sizing String Cables

# %%
pv_matrix.string_cables.set_cross_sections(4.0, 4.0)

# %% [markdown]
# ## 2.2 PV Inverter Selection

# %% [markdown]
# **SolarEdge SE5000H + power optimizer P370**

# %%
pv_inverter.setup(
    Pac_nom=5000.0,
    Vdc_nom=380.0,
    Vdc_max=480.0,
    Vmpp_min=row_num * 8,
    Vmpp_max=min(row_num * 60, 480),
    Idc_max=2 * 13.5,
    Pdc_max=7750.0,
    eff_max=99.2,
    eff_avg=99.0
)

# %% [markdown]
# **Check selected inverter with working range requirements**

# %%
results = pv_inverter.check()
msg = ''
if results:
    for result in results:
        msg = result + '<br>'
else:
    msg = 'All inverter requirements OK!'
display(HTML(msg))
# Out:
# All inverter requirements OK!

# %%
graph = pv_inverter.plot_working_range(fig_size=(14, 8), dpi=96)
graph.show_graph()

# %% [markdown]
# # 3. ENERGY ANALYSIS

# %%
ea = pv.EnergyAnalyzer(
    TMY_file='../datafiles/tmy.csv',
    CLP_file='../datafiles/mlp.csv',
    location=loc,
    pv_inverters=[pv_inverter]
)
# %time ea.analyze()
# Out:
# Wall time: 2min 22s

# %% [markdown]
# ## 3.1 Yield and Load Profiles

# %%
graph = ea.plot_profiles(fig_size=(14, 8), dpi=96)
graph.show_graph()

# %% [markdown]
# ### Annual Yield and Consumption

# %%
display(HTML(f'Annual yield = <b>{ea.get_annual_yield():.0f}</b> kWh'))
# Out:
# Annual yield = <b>5970</b> kWh

# %%
display(HTML(f'Annual load = <b>{ea.get_annual_load():.0f}</b> kWh'))
# Out:
# Annual load = <b>3774</b> kWh

# %% [markdown]
# ## 3.1 Energy Flows in PV System Without Battery Storage System

# %% [markdown]
# ### Overview Monthly Energy Flows

# %% [markdown]
# - energy flow from grid to load (Egtl, kWh) = grid supply
# - energy flow from PV system to grid (Eptg, kWh) = grid injection
# - energy flow from PV system to load (Eptl, kWh)
# - energy flow from PV system to battery (Eptb, kWh)
# - energy flow from battery to load (Ebtl, kWh)

# %%
display(HTML(ea.get_monthly_overview().to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Egtl</th>
#       <th>Eptg</th>
#       <th>Eptl</th>
#       <th>Eptb</th>
#       <th>Ebtl</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>253.817023</td>
#       <td>39.558633</td>
#       <td>63.950040</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>197.776392</td>
#       <td>109.143989</td>
#       <td>88.141515</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>189.892961</td>
#       <td>303.406630</td>
#       <td>124.955972</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>154.072253</td>
#       <td>633.110738</td>
#       <td>149.816023</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>142.157573</td>
#       <td>623.927608</td>
#       <td>166.241582</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>136.059717</td>
#       <td>750.753459</td>
#       <td>171.275484</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>149.385293</td>
#       <td>662.515517</td>
#       <td>169.069765</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>152.994939</td>
#       <td>633.836649</td>
#       <td>157.769796</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>172.878009</td>
#       <td>440.765676</td>
#       <td>135.592910</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>204.917659</td>
#       <td>217.416271</td>
#       <td>108.664843</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>232.985284</td>
#       <td>56.083378</td>
#       <td>71.290638</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>255.782101</td>
#       <td>29.548431</td>
#       <td>62.664460</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>totals</th>
#       <td>2242.719204</td>
#       <td>4500.066979</td>
#       <td>1469.433028</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#   </tbody>
# </table>

# %%
graph = ea.plot_monthly_overview(fig_size=(14, 8), dpi=96)

# %% [markdown]
# ### Self Sufficiency and Self Consumption

# %%
display(HTML(f'Self-sufficiency (i.e. percentage of annual consumption delivered by PV-system) = <b>{ea.get_self_sufficiency():.2f}</b> %'))
# Out:
# Self-sufficiency (i.e. percentage of annual consumption delivered by PV-system) = <b>39.58</b> %

# %%
graph = ea.plot_self_sufficiency(fig_size=(14, 8), dpi=96)
graph.show_graph()

# %%
display(HTML(f'Self-consumption (i.e. percentage of annual yield consumed by own loads) = <b>{ea.get_self_consumption():.2f}</b> %'))
# Out:
# Self-consumption (i.e. percentage of annual yield consumed by own loads) = <b>24.62</b> %

# %%
graph = ea.plot_self_consumption(fig_size=(14, 8), dpi=96)
graph.show_graph()

# %% [markdown]
# ### Net Consumption From Grid

# %% [markdown]
# Net consumption is the difference between energy taken from the grid and energy injected into the grid by the PV system.

# %%
display(HTML(f'Net consumption from grid = <b>{ea.get_net_consumption():.0f}</b> kWh'))
# Out:
# Net consumption from grid = <b>-2257</b> kWh

# %% [markdown]
# ## 3.2 Energy Flows In PV System With Battery Storage System

# %% [markdown]
# ### Set Up Battery

# %%
ea.battery = pv.Battery(battery_capacity=3 * 1.676)          # available battery capacity depending on load and unload current (see battery specs)
ea.battery.set_loading_params(Idc=10.0, Vdc=56.0, eff=0.9)   # battery current, load voltage and efficiency when loading
ea.battery.set_unloading_params(Idc=15.0, Vdc=48.0, eff=0.9) # battery current, load voltage and efficiency when unloading

# %% [markdown]
# ### Overview Monthly Energy Flows

# %%
Eflow_stats = ea.analyze_energy_flows()
display(HTML(ea.get_monthly_overview().to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Egtl</th>
#       <th>Eptg</th>
#       <th>Eptl</th>
#       <th>Eptb</th>
#       <th>Ebtl</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>214.258389</td>
#       <td>0.000000</td>
#       <td>63.950040</td>
#       <td>39.558633</td>
#       <td>39.558633</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>112.819217</td>
#       <td>24.186814</td>
#       <td>88.141515</td>
#       <td>84.957175</td>
#       <td>84.957175</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>41.802277</td>
#       <td>155.315946</td>
#       <td>124.955972</td>
#       <td>148.090685</td>
#       <td>148.090685</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>16.478347</td>
#       <td>495.516833</td>
#       <td>149.816023</td>
#       <td>137.593905</td>
#       <td>137.593905</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>9.765247</td>
#       <td>489.274221</td>
#       <td>166.241582</td>
#       <td>134.653386</td>
#       <td>132.392327</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>6.070467</td>
#       <td>621.138561</td>
#       <td>171.275484</td>
#       <td>129.614898</td>
#       <td>129.989249</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>11.325823</td>
#       <td>526.342756</td>
#       <td>169.069765</td>
#       <td>136.172762</td>
#       <td>138.059469</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>13.614687</td>
#       <td>494.456397</td>
#       <td>157.769796</td>
#       <td>139.380252</td>
#       <td>139.380252</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>31.262958</td>
#       <td>299.150625</td>
#       <td>135.592910</td>
#       <td>141.615051</td>
#       <td>141.615051</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>86.690225</td>
#       <td>99.188837</td>
#       <td>108.664843</td>
#       <td>118.227434</td>
#       <td>118.227434</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>179.741655</td>
#       <td>2.839748</td>
#       <td>71.290638</td>
#       <td>53.243630</td>
#       <td>53.243630</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>226.233670</td>
#       <td>0.000000</td>
#       <td>62.664460</td>
#       <td>29.548431</td>
#       <td>29.548431</td>
#     </tr>
#     <tr>
#       <th>totals</th>
#       <td>950.062963</td>
#       <td>3207.410738</td>
#       <td>1469.433028</td>
#       <td>1292.656241</td>
#       <td>1292.656241</td>
#     </tr>
#   </tbody>
# </table>

# %%
graph = ea.plot_monthly_overview(fig_size=(14, 8), dpi=96)
graph.show_graph()

# %% [markdown]
# ### Self Sufficiency and Self Consumption

# %%
display(HTML(f'Self-sufficiency (i.e. percentage of annual consumption delivered by PV-system) = <b>{ea.get_self_sufficiency():.2f}</b> %'))
# Out:
# Self-sufficiency (i.e. percentage of annual consumption delivered by PV-system) = <b>74.41</b> %

# %%
graph = ea.plot_self_sufficiency(fig_size=(14, 8), dpi=96)
graph.show_graph()

# %%
display(HTML(f'Self-consumption (i.e. percentage of annual yield consumed by own loads) = <b>{ea.get_self_consumption():.2f}</b> %'))
# Out:
# Self-consumption (i.e. percentage of annual yield consumed by own loads) = <b>46.27</b> %

# %%
graph = ea.plot_self_consumption(fig_size=(14, 8), dpi=96)
graph.show_graph()

# %% [markdown]
# **Self sufficiency as function of battery capacity**

# %%
from nummath import graphing

battery_capacities = [i for i in range(1, 26)]
self_sufficiency = []
for battery_capacity in battery_capacities:
    ea.battery = pv.Battery(battery_capacity)
    ea.analyze_energy_flows()
    self_sufficiency.append(ea.get_self_sufficiency())

graph = graphing.Graph(fig_size=(8, 6), dpi=96)
graph.add_data_set(name='none', x=battery_capacities, y=self_sufficiency, marker='o')
graph.set_axis_titles(x_title='battery capacity [kWh]', y_title='self-sufficiency [%]')
graph.turn_grid_on()
graph.draw_graph()
graph.show_graph()

# %% [markdown]
# ### Net Consumption From Grid

# %%
display(HTML(f'Net consumption from grid = <b>{ea.get_net_consumption():.0f}</b> kWh'))
# Out:
# Net consumption from grid = <b>-2257</b> kWh
