# %%
import sys
sys.path.append('D:/Python/Projecten/pypv/lib')  # add my own lib folder to Python's search path
sys.path.append('D:/Python/Projecten/pypv/datafiles')  # add the folder with the py-script for the horizon profiles

# %%
from IPython.display import HTML
import sun
import photovoltaic as pv
from quantities.date_time import Date, ANY_YEAR

# %% [markdown]
# # 1. PV SYSTEM DESIGN

# %% [markdown]
# ## 1.1 Set Up Geographic Location and Horizon Profiles

# %%
loc = sun.Location(
    name='Ghent',
    region='Belgium',
    latitude=51.07,
    longitude=3.69,
    altitude=9.0
)

# %% [markdown]
# **Import horizon profiles from Python script 'horizon_profiles.py'**

# %%
from horizon_profiles import hp_01, hp_02

# %% [markdown]
# **Plot sun path diagrams with horizon profile 'hp_01' (front of flat roof)**

# %%
spl = [sun.SunPath(loc, Date(ANY_YEAR, m, 21)) for m in range(1, 13)]
p = sun.plot_sun_path_diagram(spl, hp_01, size=(14, 8), dpi=96)
p.show_graph()

# %% [markdown]
# **Plot sun path diagram with horizon profile 'hp_02' (at the end of the flat roof)**

# %%
p = sun.plot_sun_path_diagram(spl, hp_02, size=(14, 8), dpi=96)
p.show_graph()

# %% [markdown]
# ## 1.2 Set Up PV Matrices

# %% [markdown]
# ### Solar Panels

# %% [markdown]
# **Photovoltaic specifications of solar panels**

# %%
pv_char = pv.PhotoVoltaicCharacteristics(
    pv.STC(Isc=9.97, Voc=39.4, Impp=9.63, Vmpp=31.2),
    pv.TemperatureCoefficients(cIsc=0.05, cVoc=-0.29, cPmpp=-0.4),
    noct=48.0
)

# %% [markdown]
# **Solar panel with eastern orientation**

# %%
solar_panel_east_hp01 = pv.SolarPanel(
    loc=loc,
    orient=pv.Orientation(azimuth=78.0, tilt=20.0),
    dim=pv.Dimensions(width=0.99, height=1.66),
    pv_char=pv_char,
    hz_profile=hp_01
)

# %%
solar_panel_east_hp02 = pv.SolarPanel(
    loc=loc,
    orient=pv.Orientation(azimuth=78.0, tilt=20.0),
    dim=pv.Dimensions(width=0.99, height=1.66),
    pv_char=pv_char,
    hz_profile=hp_02
)

# %% [markdown]
# **Solar panel with western orientation**

# %%
solar_panel_west_hp01 = pv.SolarPanel(
    loc=loc,
    orient=pv.Orientation(azimuth=258.0, tilt=20.0),
    dim=pv.Dimensions(width=0.99, height=1.66),
    pv_char=pv_char,
    hz_profile=hp_01
)

# %%
solar_panel_west_hp02 = pv.SolarPanel(
    loc=loc,
    orient=pv.Orientation(azimuth=258.0, tilt=20.0),
    dim=pv.Dimensions(width=0.99, height=1.66),
    pv_char=pv_char,
    hz_profile=hp_02
)

# %% [markdown]
# ### Solar Panel Matrices

# %% [markdown]
# **PV matrix 1 with eastern orientation**

# %%
row_num = 9  # number of solar panels in one string
col_num = 1  # number of strings

pv_matrix_east = pv.SolarPanelMatrix('PVM-east', row_num=row_num, col_num=col_num)
for r in range(row_num):
    for c in range(col_num):
        if 0 <= r < 5:
            pv_matrix_east.add_solar_panel(solar_panel_east_hp01, r, c)
        if 5 <= r < 9:
            pv_matrix_east.add_solar_panel(solar_panel_east_hp02, r, c)

# %% [markdown]
# **PV matrix 2 with western orientation**

# %%
row_num = 9
col_num = 1

pv_matrix_west = pv.SolarPanelMatrix('PVM-west', row_num=row_num, col_num=col_num)
for r in range(row_num):
    for c in range(col_num):
        if 0 <= r < 5:
            pv_matrix_west.add_solar_panel(solar_panel_west_hp01, r, c)
        if 5 <= r < 9:
            pv_matrix_west.add_solar_panel(solar_panel_west_hp02, r, c)

# %% [markdown]
# **PV matrix performance at STC**

# %%
for pv_matrix in (pv_matrix_east, pv_matrix_west):
    display(HTML(f'<b>Performance of PV matrix {pv_matrix.id} at STC</b>'))
    pv_matrix.set_operating_conditions(Gsurf=1000.0, Tcell=25.0)  # STC conditions
    display(HTML(f'- peak power = <b>{pv_matrix.get_mpp_power() / 1000.0:.1f}</b> kWp'))
    display(HTML(f'- MPP current = <b>{pv_matrix.get_mpp_current():.1f}</b> A'))
    display(HTML(f'- MPP voltage = <b>{pv_matrix.get_mpp_voltage():.1f}</b> V'))
    display(HTML(f'- short circuit current = <b>{pv_matrix.get_sc_current():.1f}</b> A'))
    display(HTML(f'- open circuit voltage = <b>{pv_matrix.get_oc_voltage():.1f}</b> V'))
# Out:
# <b>Performance of PV matrix PVM-east at STC</b>
# - peak power = <b>2.7</b> kWp
# - MPP current = <b>9.6</b> A
# - MPP voltage = <b>280.8</b> V
# - short circuit current = <b>10.0</b> A
# - open circuit voltage = <b>354.6</b> V
# <b>Performance of PV matrix PVM-west at STC</b>
# - peak power = <b>2.7</b> kWp
# - MPP current = <b>9.6</b> A
# - MPP voltage = <b>280.8</b> V
# - short circuit current = <b>10.0</b> A
# - open circuit voltage = <b>354.6</b> V

# %% [markdown]
# **Required cross section of string cables**

# %%
for pv_matrix in (pv_matrix_east, pv_matrix_west):
    pv_matrix.string_cables.set_cable_lengths(25)
    cs_min = pv_matrix.string_cables.calc_min_cross_sections()
    display(HTML(f'min. required string cable cross section {pv_matrix.id} = <b>{cs_min[0]:.1f}</b> mm²'))
# Out:
# min. required string cable cross section PVM-east = <b>3.2</b> mm²
# min. required string cable cross section PVM-west = <b>3.2</b> mm²

# %% [markdown]
# ## 1.3 Set Up PV Inverters

# %% [markdown]
# **Add PV matrices to inverter**

# %%
pv_inverter = pv.Inverter('INVERTER')
for pv_matrix in (pv_matrix_east, pv_matrix_west):
    pv_inverter.add_pv_matrix(pv_matrix)

# %% [markdown]
# **Inverter working range requirements**

# %%
inv_req = pv_inverter.get_requirements()
display(HTML(
    f"- Minimum value of nominal AC power: <b>{inv_req['Pac_min'][0] / 1000.0:.3f}</b> kW<br>"
    f"- Maximum value of nominal AC power: <b>{inv_req['Pac_max'][0] / 1000.0:.3f}</b> kW<br>"
    f"- Minimum value of maximum DC voltage: <b>{inv_req['Vdc_max'][0]:.3f}</b> V<br>"
    f"- Maximum value of minimum MPP voltage: <b>{inv_req['Vmpp_min'][0]:.3f}</b> V<br>"
    f"- Minimum value of maximum DC current: <b>{inv_req['Idc_max'][0]:.3f}</b> A<br>"
    f"- Minimum value of maximum DC power: <b>{inv_req['Pdc_max'][0] / 1000.0:.3f}</b> kW."
))
# Out:
# - Minimum value of nominal AC power: <b>4.327</b> kW<br>- Maximum value of nominal AC power: <b>6.490</b> kW<br>- Minimum value of maximum DC voltage: <b>390.592</b> V<br>- Maximum value of minimum MPP voltage: <b>244.156</b> V<br>- Minimum value of maximum DC current: <b>12.038</b> A<br>- Minimum value of maximum DC power: <b>5.601</b> kW.

# %%
graph = pv_inverter.plot_working_range(required_range=True, fig_size=(14, 8), dpi=96)
graph.show_graph()

# %% [markdown]
# # 2. SIZING PV SYSTEM

# %% [markdown]
# ## 2.1 Sizing String Cables

# %%
pv_matrix_east.string_cables.set_cross_sections(4.0)
pv_matrix_west.string_cables.set_cross_sections(4.0)

# %% [markdown]
# ## 2.2 PV Inverter Selection

# %% [markdown]
# **SMA Sunny Boy 5.0 (SB5.0-1AV-40)**

# %%
pv_inverter.setup(
    Pac_nom=5000.0,
    Vdc_nom=365.0,
    Vdc_max=600.0,
    Vmpp_min=175.0,
    Vmpp_max=500.0,
    Idc_max=15.0,
    Pdc_max=7500.0,
    eff_max=97.0
)

# %% [markdown]
# **Inverter efficiencies**

# %%
pv_inverter.set_part_load_efficiencies(
    eff_at_Vmpp_min={5: 91.2, 10: 93.8, 20: 95.3, 25: 95.5, 30: 95.6, 50: 95.6, 75: 95.2, 100: 94.6},
    eff_at_Vdc_nom={5: 92.5, 10: 95.2, 20: 96.6, 25: 96.8, 30: 97.0, 50: 97.0, 75: 96.7, 100: 96.2},
    eff_at_Vmpp_max={5: 90.7, 10: 94.4, 20: 96.2, 25: 96.5, 30: 96.6, 50: 96.8, 75: 96.5, 100: 96.1}
)

# %%
graph = pv_inverter.plot_efficiency_curves(fig_size=(14, 8), dpi=96)
# Out:
# Error in callback <function flush_figures at 0x0F6B4F60> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\python\virtualenvironments\pypv\lib\site-packages\ipykernel\pylab\backend_inline.py in flush_figures()
#     115         # ignore the tracking, just draw and close all figures
#     116         try:
# --> 117             return show(True)
#     118         except Exception as e:
#     119             # safely show traceback if in IPython, else raise
#
# d:\python\virtualenvironments\pypv\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# d:\python\virtualenvironments\pypv\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     304             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     305         else:
# --> 306             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     307             if not format_dict:
#     308                 # nothing to display (e.g. _ipython_display_ took over)
#
# d:\python\virtualenvironments\pypv\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <d:\python\virtualenvironments\pypv\lib\site-packages\decorator.py:decorator-gen-9> in __call__(self, obj)
#
# d:\python\virtualenvironments\pypv\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# d:\python\virtualenvironments\pypv\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# d:\python\virtualenvironments\pypv\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# d:\python\virtualenvironments\pypv\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# d:\python\virtualenvironments\pypv\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2058                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#    2059                     bbox_inches = self.figure.get_tightbbox(renderer,
# -> 2060                             bbox_extra_artists=bbox_artists)
#    2061                     pad = kwargs.pop("pad_inches", None)
#    2062                     if pad is None:
#
# d:\python\virtualenvironments\pypv\lib\site-packages\matplotlib\figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    2365
#    2366         for a in artists:
# -> 2367             bbox = a.get_tightbbox(renderer)
#    2368             if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    2369                 bb.append(bbox)
#
# d:\python\virtualenvironments\pypv\lib\site-packages\matplotlib\axes\_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists)
#    4353
#    4354         if self.axison:
# -> 4355             bb_xaxis = self.xaxis.get_tightbbox(renderer)
#    4356             if bb_xaxis:
#    4357                 bb.append(bb_xaxis)
#
# d:\python\virtualenvironments\pypv\lib\site-packages\matplotlib\axis.py in get_tightbbox(self, renderer)
#    1160             return
#    1161
# -> 1162         ticks_to_draw = self._update_ticks()
#    1163
#    1164         self._update_label_position(renderer)
#
# d:\python\virtualenvironments\pypv\lib\site-packages\matplotlib\axis.py in _update_ticks(self)
#    1077         the axes.  Return the list of ticks that will be drawn.
#    1078         """
# -> 1079         major_locs = self.get_majorticklocs()
#    1080         major_labels = self.major.formatter.format_ticks(major_locs)
#    1081         major_ticks = self.get_major_ticks(len(major_locs))
#
# d:\python\virtualenvironments\pypv\lib\site-packages\matplotlib\axis.py in get_majorticklocs(self)
#    1322     def get_majorticklocs(self):
#    1323         """Get the array of major tick locations in data coordinates."""
# -> 1324         return self.major.locator()
#    1325
#    1326     def get_minorticklocs(self):
#
# d:\python\virtualenvironments\pypv\lib\site-packages\matplotlib\ticker.py in __call__(self)
#    2076     def __call__(self):
#    2077         vmin, vmax = self.axis.get_view_interval()
# -> 2078         return self.tick_values(vmin, vmax)
#    2079
#    2080     def tick_values(self, vmin, vmax):
#
# d:\python\virtualenvironments\pypv\lib\site-packages\matplotlib\ticker.py in tick_values(self, vmin, vmax)
#    2084         vmin, vmax = mtransforms.nonsingular(
#    2085             vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 2086         locs = self._raw_ticks(vmin, vmax)
#    2087
#    2088         prune = self._prune
#
# d:\python\virtualenvironments\pypv\lib\site-packages\matplotlib\ticker.py in _raw_ticks(self, vmin, vmax)
#    2023         if self._nbins == 'auto':
#    2024             if self.axis is not None:
# -> 2025                 nbins = np.clip(self.axis.get_tick_space(),
#    2026                                 max(1, self._min_n_ticks - 1), 9)
#    2027             else:
#
# d:\python\virtualenvironments\pypv\lib\site-packages\matplotlib\axis.py in get_tick_space(self)
#    2180         ends = self.axes.transAxes.transform([[0, 0], [1, 0]])
#    2181         length = ((ends[1][0] - ends[0][0]) / self.axes.figure.dpi) * 72
# -> 2182         tick = self._get_tick(True)
#    2183         # There is a heuristic here that the aspect ratio of tick text
#    2184         # is no more than 3:1
#
# d:\python\virtualenvironments\pypv\lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    1931         else:
#    1932             tick_kw = self._minor_tick_kw
# -> 1933         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1934
#    1935     def _get_label(self):
#
# d:\python\virtualenvironments\pypv\lib\site-packages\matplotlib\axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     156         self.apply_tickdir(tickdir)
#     157
# --> 158         self.tick1line = self._get_tick1line()
#     159         self.tick2line = self._get_tick2line()
#     160         self.gridline = self._get_gridline()
#
# d:\python\virtualenvironments\pypv\lib\site-packages\matplotlib\axis.py in _get_tick1line(self)
#     462                           linestyle='None', marker=self._tickmarkers[0],
#     463                           markersize=self._size,
# --> 464                           markeredgewidth=self._width, zorder=self._zorder)
#     465         l.set_transform(self.axes.get_xaxis_transform(which='tick1'))
#     466         self._set_artist_props(l)
#
# d:\python\virtualenvironments\pypv\lib\site-packages\matplotlib\lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     380         self._color = None
#     381         self.set_color(color)
# --> 382         self._marker = MarkerStyle(marker, fillstyle)
#     383
#     384         self._markevery = None
#
# d:\python\virtualenvironments\pypv\lib\site-packages\matplotlib\markers.py in __init__(self, marker, fillstyle)
#     241         self._marker_function = None
#     242         self.set_fillstyle(fillstyle)
# --> 243         self.set_marker(marker)
#     244
#     245     def _recache(self):
#
# d:\python\virtualenvironments\pypv\lib\site-packages\matplotlib\markers.py in set_marker(self, marker)
#     314
#     315         self._marker = marker
# --> 316         self._recache()
#     317
#     318     def get_path(self):
#
# d:\python\virtualenvironments\pypv\lib\site-packages\matplotlib\markers.py in _recache(self)
#     254         self._capstyle = 'butt'
#     255         self._filled = True
# --> 256         self._marker_function()
#     257
#     258     def __bool__(self):
#
# d:\python\virtualenvironments\pypv\lib\site-packages\matplotlib\markers.py in _set_tickdown(self)
#     767
#     768     def _set_tickdown(self):
# --> 769         self._transform = Affine2D().scale(1.0, -1.0)
#     770         self._snap_threshold = 1.0
#     771         self._filled = False
#
# d:\python\virtualenvironments\pypv\lib\site-packages\matplotlib\transforms.py in scale(self, sx, sy)
#    1989         scale_mtx = np.array(
#    1990             [[sx, 0.0, 0.0], [0.0, sy, 0.0], [0.0, 0.0, 1.0]], float)
# -> 1991         self._mtx = np.dot(scale_mtx, self._mtx)
#    1992         self.invalidate()
#    1993         return self
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# **Check selected inverter with working range requirements**

# %%
results = pv_inverter.check()
msg = ''
if results:
    for result in results:
        msg = result + '<br>'
else:
    msg = 'All inverter requirements are fulfilled!'
display(HTML(msg))
# Out:
# All inverter requirements are fulfilled!

# %%
graph = pv_inverter.plot_working_range(fig_size=(14, 8), dpi=96)
graph.show_graph()

# %% [markdown]
# # 3. ENERGY ANALYSIS

# %%
ea = pv.EnergyAnalyzer(
    TMY_file='../datafiles/tmy.csv',
    CLP_file='../datafiles/mlp.csv',
    location=loc,
    pv_inverters=[pv_inverter]
)
# %time ea.analyze()

# %% [markdown]
# ## 3.1 Yield and Load Profiles

# %%
graph = ea.plot_profiles(fig_size=(14, 8), dpi=96)
graph.show_graph()

# %% [markdown]
# ### Annual Yield and Consumption

# %%
display(HTML(f'Annual yield = <b>{ea.get_annual_yield():.0f}</b> kWh'))

# %%
display(HTML(f'Annual load = <b>{ea.get_annual_load():.0f}</b> kWh'))

# %% [markdown]
# ## 3.1 Energy Flows in PV System Without Battery Storage System

# %% [markdown]
# ### Overview Monthly Energy Flows

# %% [markdown]
# - energy flow from grid to load (Egtl, kWh) = grid supply
# - energy flow from PV system to grid (Eptg, kWh) = grid injection
# - energy flow from PV system to load (Eptl, kWh)
# - energy flow from PV system to battery (Eptb, kWh)
# - energy flow from battery to load (Ebtl, kWh)

# %%
display(HTML(ea.get_monthly_overview().to_html()))

# %%
graph = ea.plot_monthly_overview(fig_size=(14, 8), dpi=96)

# %% [markdown]
# ### Self Sufficiency and Self Consumption

# %%
display(HTML(f'Self-sufficiency (i.e. percentage of annual consumption delivered by PV-system) = <b>{ea.get_self_sufficiency():.2f}</b> %'))

# %%
graph = ea.plot_self_sufficiency(fig_size=(14, 8), dpi=96)
graph.show_graph()

# %%
display(HTML(f'Self-consumption (i.e. percentage of annual yield consumed by own loads) = <b>{ea.get_self_consumption():.2f}</b> %'))

# %%
graph = ea.plot_self_consumption(fig_size=(14, 8), dpi=96)
graph.show_graph()

# %% [markdown]
# ### Net Consumption From Grid

# %% [markdown]
# Net consumption is the difference between energy taken from the grid and energy injected into the grid by the PV system.

# %%
display(HTML(f'Net consumption from grid = <b>{ea.get_net_consumption():.0f}</b> kWh'))

# %% [markdown]
# ## 3.2 Energy Flows In PV System With Battery Storage System

# %% [markdown]
# ### Set Up Battery

# %%
ea.battery = pv.Battery(battery_capacity=3 * 1.676)          # available battery capacity depending on load and unload current (see battery specs)
ea.battery.set_loading_params(Idc=10.0, Vdc=56.0, eff=0.9)   # battery current, load voltage and efficiency when loading
ea.battery.set_unloading_params(Idc=15.0, Vdc=48.0, eff=0.9) # battery current, load voltage and efficiency when unloading

# %% [markdown]
# ### Overview Monthly Energy Flows

# %%
Eflow_stats = ea.analyze_energy_flows()
display(HTML(ea.get_monthly_overview().to_html()))

# %%
graph = ea.plot_monthly_overview(fig_size=(14, 8), dpi=96)
graph.show_graph()

# %% [markdown]
# ### Self Sufficiency and Self Consumption

# %%
display(HTML(f'Self-sufficiency (i.e. percentage of annual consumption delivered by PV-system) = <b>{ea.get_self_sufficiency():.2f}</b> %'))

# %%
graph = ea.plot_self_sufficiency(fig_size=(14, 8), dpi=96)
graph.show_graph()

# %%
display(HTML(f'Self-consumption (i.e. percentage of annual yield consumed by own loads) = <b>{ea.get_self_consumption():.2f}</b> %'))

# %%
graph = ea.plot_self_consumption(fig_size=(14, 8), dpi=96)
graph.show_graph()

# %% [markdown]
# **Self sufficiency as function of battery capacity**

# %%
from nummath import graphing

battery_capacities = [i for i in range(1, 26)]
self_sufficiency = []
for battery_capacity in battery_capacities:
    ea.battery = pv.Battery(battery_capacity)
    ea.analyze_energy_flows()
    self_sufficiency.append(ea.get_self_sufficiency())

graph = graphing.Graph(fig_size=(8, 6), dpi=96)
graph.add_data_set(name='none', x=battery_capacities, y=self_sufficiency, marker='o')
graph.set_axis_titles(x_title='battery capacity [kWh]', y_title='self-sufficiency [%]')
graph.turn_grid_on()
graph.draw_graph()
graph.show_graph()

# %% [markdown]
# ### Net Consumption From Grid

# %%
display(HTML(f'Net consumption from grid = <b>{ea.get_net_consumption():.0f}</b> kWh'))
